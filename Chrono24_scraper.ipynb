# %%
import re
import time
import random
import requests
import unidecode
import pandas as pd
from bs4 import BeautifulSoup as bs
from itertools import chain
from collections import defaultdict




# from google.colab import drive
# drive.mount('drive')

# %%
# ua = UserAgent()

# %%
def get_brand_list():
    url = 'https://www.chrono24.com/search/browse.htm?char=A-Z'
    headers = {'accept': '*/*',
 'accept-encoding': 'gzip, deflate',
 'accept-language': 'pt-PT,pt;q=0.9,en-US;q=0.8,en;q=0.7',
 'cookie': 'uid=9c718efe-dcca-4e71-b92d-c3dd7b7f06cc',
 'referer': 'https://a3853408329f84107a5d2b90c11d7c4b.safeframe.googlesyndication.com/',
 'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Google Chrome";v="98"',
 'sec-ch-ua-mobile': '?0',
 'sec-ch-ua-platform': '"Windows"',
 'sec-fetch-dest': 'empty',
 'sec-fetch-mode': 'cors',
 'sec-fetch-site': 'same-origin',
 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36'}
    
    
    r = requests.get(url, headers=headers)

    ChronoBS = bs(r.text, 'html.parser')

    get_brands = ChronoBS.find_all("div", {"class":"brand-list"})[-1].get_text()

    brands = []

    def Convert(string):
        normalized_string = unidecode.unidecode(string)
        brands = list(normalized_string.split("\n"))
        new_list=[x for x in brands if len(x)>=2]
        return new_list

    r = [re.sub('[^a-zA-Z0-9]+', '', _) for _ in Convert(get_brands)]

    brands_df = pd.DataFrame(r, columns = ['Brand'])
    brands_df.drop(brands_df.tail(1).index,inplace=True)
    brands_df = brands_df.applymap(lambda s: s.lower() if type(s) == str else s)
    brands_df.to_csv('brands_list.csv', sep = ',', index = False)
    return brands_df

# %%
# get_brand_list()

# %%
def get_links_from_single_page(url):   
    links = []
    
    #to add reference to variable brand. Rolex link is placeholder
    #url = f'https://www.chrono24.com/{brand}/index.htm'

    headers = {'accept': '*/*',
 'accept-encoding': 'gzip, deflate',
 'accept-language': 'pt-PT,pt;q=0.9,en-US;q=0.8,en;q=0.7',
 'cookie': 'uid=9c718efe-dcca-4e71-b92d-c3dd7b7f06cc',
 'referer': 'https://a3853408329f84107a5d2b90c11d7c4b.safeframe.googlesyndication.com/',
 'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Google Chrome";v="98"',
 'sec-ch-ua-mobile': '?0',
 'sec-ch-ua-platform': '"Windows"',
 'sec-fetch-dest': 'empty',
 'sec-fetch-mode': 'cors',
 'sec-fetch-site': 'same-origin',
 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36'}


    r = requests.get(url, headers=headers)

    soup = bs(r.text, 'html.parser')

    data = soup.findAll('div', {"class":"article-item-container wt-search-result"})

    for div in data:
        link = div.findAll('a')
        for a in link:
            links.append("https://www.chrono24.com" + a['href'])

    #links.remove('https://www.chrono24.com/about-us.htm')
    
    return links

# %%
#get_links_from_single_page('audemarspiguet')

# %%
def get_max_pages(brand):
    
    #to add reference to variable brand. Rolex link is placeholder
    url = f'https://www.chrono24.com/{brand}/index.htm'

    headers = {'accept': '*/*',
 'accept-encoding': 'gzip, deflate',
 'accept-language': 'pt-PT,pt;q=0.9,en-US;q=0.8,en;q=0.7',
 'cookie': 'uid=9c718efe-dcca-4e71-b92d-c3dd7b7f06cc',
 'referer': 'https://a3853408329f84107a5d2b90c11d7c4b.safeframe.googlesyndication.com/',
 'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Google Chrome";v="98"',
 'sec-ch-ua-mobile': '?0',
 'sec-ch-ua-platform': '"Windows"',
 'sec-fetch-dest': 'empty',
 'sec-fetch-mode': 'cors',
 'sec-fetch-site': 'same-origin',
 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36'}

    r = requests.get(url, headers=headers)

    soup = bs(r.text, 'html.parser')

    data = soup.findAll('ul', {"class":"pagination list-unstyled pull-xs-none pull-sm-right"})
    
    li = []
    for ultag in data:
        for litag in ultag.find_all('li'):
            normalized_li = litag.text.split("\n")
            new_list=[x for x in normalized_li if len(x)>=1]
            li.append(new_list)
    flat_li = [item for sublist in li for item in sublist]
    flat_li = [re.sub('[^a-zA-Z0-9]+', '', _) for _ in flat_li]

    # index = 1

    if len(flat_li) > 1:
        index = int(flat_li[-2])
    else:
        index = 1

    return index

# %%
#Get ad info... brand, model, reference, etc.

def fetch_attributes(url):

    #to add reference to variable brand. Rolex link is placeholder
    #url = 'https://www.chrono24.com/rolex/rolex-gmt-master-ii-2020-batman--batgirl-ref-126710blnr-ceramic-jubilee-stainless-steel--id20749471.htm'

    headers = {'accept': '*/*',
 'accept-encoding': 'gzip, deflate',
 'accept-language': 'pt-PT,pt;q=0.9,en-US;q=0.8,en;q=0.7',
 'cookie': 'uid=9c718efe-dcca-4e71-b92d-c3dd7b7f06cc',
 'referer': 'https://a3853408329f84107a5d2b90c11d7c4b.safeframe.googlesyndication.com/',
 'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Google Chrome";v="98"',
 'sec-ch-ua-mobile': '?0',
 'sec-ch-ua-platform': '"Windows"',
 'sec-fetch-dest': 'empty',
 'sec-fetch-mode': 'cors',
 'sec-fetch-site': 'same-origin',
 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36'}

    r = requests.get(url, headers=headers)

    soup = bs(r.text, 'html.parser')

    data = soup.findAll('div', {"class":"col-xs-24 col-md-12 m-b-6 m-b-md-0"})
    
    li = []
    for tag in data:
            for trtag in tag.find_all('tr'):
                normalized_tr = trtag.text.split("\n")
                new_list=[x for x in normalized_tr if len(x)>=2]
                li.append(new_list)
    attributes_dict = {x[0]: x[1:] for x in li}
    new_dict = {k: str(v).replace('[','').replace(']', '') for k,v in attributes_dict.items()}
    new_dict = {k: str(v).replace("'",'').strip() for k,v in new_dict.items()}
    new_dict = {k: str(v).replace('"','').strip() for k,v in new_dict.items()}
    clean_attributes = {k: v for k, v in new_dict.items() if v != ''}
    return clean_attributes

# %%
brands_list = pd.read_csv('brands_list.csv')
brands_list
# Out:
#                Brand
# 0       alangesoehne
# 1           abpparis
# 2    adchronographen
# 3          aerowatch
# 4              aigle
# ..               ...
# 485   zenowatchbasel
# 486           zentra
# 487         zeppelin
# 488           zodiac
# 489              zrc
#
# [490 rows x 1 columns]

# %%
def get_all_links():

    all_links = []
    for brand in brands_list['Brand']:
        
        time.sleep(0.75)
        
        for index in range(1, get_max_pages(brand)+1):
            
            if index == 1:
                all_links.append(f'https://www.chrono24.com/{brand}/index.htm')
                print (f'https://www.chrono24.com/{brand}/index.htm')
            else:
                all_links.append(f'https://www.chrono24.com/{brand}/index-{index}.htm')
                print (f'https://www.chrono24.com/{brand}/index-{index}.htm')
#         time.sleep(0.25)


    links_df = pd.DataFrame(all_links, columns = ['Brand'])
    links_df.drop(links_df.tail(1).index,inplace=True)
    links_df = links_df.applymap(lambda s: s.lower() if type(s) == str else s)
    links_df.to_csv('link_list.csv', sep = ',', index = False)

    #return all_links

# %%
#get_all_links()

# %%
link_list = pd.read_csv('link_list.csv')
link_list
# Out:
#                                                   Brand
# 0       https://www.chrono24.com/alangesoehne/index.htm
# 1     https://www.chrono24.com/alangesoehne/index-2.htm
# 2     https://www.chrono24.com/alangesoehne/index-3.htm
# 3     https://www.chrono24.com/alangesoehne/index-4.htm
# 4     https://www.chrono24.com/alangesoehne/index-5.htm
# ...                                                 ...
# 7887        https://www.chrono24.com/zodiac/index-3.htm
# 7888        https://www.chrono24.com/zodiac/index-4.htm
# 7889        https://www.chrono24.com/zodiac/index-5.htm
# 7890        https://www.chrono24.com/zodiac/index-6.htm
# 7891             https://www.chrono24.com/zrc/index.htm
#
# [7892 rows x 1 columns]

# %%
def get_all_ads():

    ad_links = []
    for link in link_list['Brand']:
            ad = (get_links_from_single_page(link))
            ad_links.append(ad)
            print(str(ad))
            
    flat_li = [item for sublist in ad_links for item in sublist]
    flat_li.remove('https://www.chrono24.com/about-us.htm')
    
    ad_df = pd.DataFrame(flat_li, columns = ['Brand'])
    ad_df.drop(ad_df.tail(1).index,inplace=True)
    ad_df.to_csv('ad_list.csv', sep = ',', index = False)
    
    
#     return flat_li

# %%
#get_all_ads()

# %%
ad_list = pd.read_csv('ad_list.csv')
# ad_list = ad_list.head(100)
ad_list
# Out:
#                                                     Brand
# 0       https://www.chrono24.com/alangesoehne/a-lange-...
# 1       https://www.chrono24.com/alangesoehne/a-lange-...
# 2       https://www.chrono24.com/alangesoehne/datograp...
# 3       https://www.chrono24.com/alangesoehne/a-lange-...
# 4       https://www.chrono24.com/alangesoehne/lange-1-...
# ...                                                   ...
# 463279  https://www.chrono24.com/zrc/grands-fonds-300m...
# 463280  https://www.chrono24.com/zrc/zrc-french-navy-r...
# 463281  https://www.chrono24.com/zrc/zrc-gf41198-case-...
# 463282  https://www.chrono24.com/zrc/zrc-grands-fonds-...
# 463283  https://www.chrono24.com/zrc/zrc-grands-fonds-...
#
# [463284 rows x 1 columns]

# %%
def get_all_attributes():
    
    base_dict = {'Listing code': [],
                         'Brand': [],
                         'Model': [],
                         'Reference number': [],
                         'Movement': [],
                         'Case material': [],
                         'Bracelet material': [],
                         'Year of production': [],
                         'Condition': [],
                         'Scope of delivery': [],
                         'Gender': [],
                         'Location': [],
                         'Movement/Caliber': [],
                         'Base caliber': [],
                         'Power reserve': [],
                         'Number of jewels': [],
                         'Case diameter': [],
                         'Water resistance': [],
                         'Bezel material': [],
                         'Crystal': [],
                         'Dial': [],
                         'Dial numerals': [],
                         'Bracelet color': [],
                         'Clasp': [],
                         'Clasp material': []}



    for link in ad_list['Brand']:
        
        try:
            dict_2 = fetch_attributes(link)
            print(dict_2)
            for k, v in dict_2.items():
                if k in base_dict.keys():
                    base_dict[k].append(v)
                #time.sleep(random.uniform(0.1, 0.5)) 
                
        except requests.exceptions.RequestException as e:
            print(f'Link exceeded max retries: {link}')
            continue
            
            
    return base_dict

# %%
power = get_all_attributes()
# Out:
# {'Listing code': 'DGN2P1', 'Brand': 'A. Lange & Söhne', 'Model': 'Zeitwerk', 'Reference number': '140.025', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': '2009', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, Westchester County', 'Movement/Caliber': 'L043.1, 36', 'Case diameter': '42 mm', 'Dial': 'Silver'}
# {'Listing code': 'C9WCV0', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '233.026', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2010', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Orlando', 'Power reserve': '55 h', 'Case diameter': '40 mm', 'Water resistance': '3 ATM', 'Bezel material': 'White gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver (solid)', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'DC2H49', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '403.031', 'Dealer product code': '40395', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Year of production': 'Unknown', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Massachusetts, Boston', 'Case diameter': '39 mm', 'Thickness': '13 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial numerals': 'Roman numerals'}
# {'Listing code': 'C9KGV9', 'Brand': 'A. Lange & Söhne', 'Model': 'Zeitwerk', 'Reference number': '140.029', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Year of production': '2016', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Georgia, Alpharetta', 'Movement/Caliber': 'L043.1', 'Power reserve': '36 h', 'Number of jewels': '68', 'Case diameter': '41.9 mm', 'Water resistance': '3 ATM', 'Bezel material': 'White gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'D7W4Y6', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '101.031', 'Dealer product code': '210000009828', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Illinois, BUFFALO GROVE', 'Case diameter': '38.5 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Clasp': 'Buckle'}
# {'Listing code': 'COMJG7', 'Brand': 'A. Lange & Söhne', 'Model': 'Grand Lange 1', 'Reference number': '139.032', 'Dealer product code': 'ALEF07009', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Leather', 'Year of production': '2019', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, New York', 'Movement/Caliber': 'L095.3', 'Power reserve': '72 h', 'Case diameter': '41 mm', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'CZNJ89', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '410.025', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': '2021', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Hong Kong, Hong Kong', 'Movement/Caliber': 'L952.1', 'Power reserve': '36 h', 'Number of jewels': '45', 'Case diameter': '41 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'Platinum'}
# {'Listing code': '3TBMW1', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '720.032', 'Dealer product code': '13026', 'Movement': 'Automatic', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2014', 'Condition': 'Unworn,                      (Mint condition, without signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Texas, Houston', 'Movement/Caliber': 'L082.1', 'Power reserve': '50 h', 'Case diameter': '41.9 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'No numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'DEXCA2', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '109.025', 'Dealer product code': '40321', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Leather', 'Year of production': '2013', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Georgia, Atlanta', 'Case diameter': '38.5 mm', 'Thickness': '10 mm', 'Bezel material': 'Platinum', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Black', 'Clasp material': 'Platinum'}
# {'Listing code': 'CLF489', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Dealer product code': '2108342', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2014', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Karlsruhe', 'Movement/Caliber': 'L941.1', 'Case diameter': '37 mm', 'Thickness': '7.5 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Bracelet color': 'Black', 'Bracelet length': '190 mm', 'Lug width': '19 mm, Size guide', 'Clasp': 'Buckle'}
# {'Listing code': 'D51GT2', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '219.032', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2016', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Tennesse, Knoxville', 'Power reserve': '45 h', 'Case diameter': '35 x 6 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'No numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'Red gold'}
# {'Listing code': 'DC2H92', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '403.035', 'Dealer product code': '40490', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Massachusetts, Boston', 'Case diameter': '39 mm', 'Thickness': '13 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal'}
# {'Listing code': 'D9C242', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '405.035', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': '2021', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Georgia, Alpharetta', 'Movement/Caliber': 'L951.6', 'Power reserve': '60 h', 'Number of jewels': '46', 'Case diameter': '41 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Platinum', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Dial numerals': 'No numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'Platinum'}
# {'Listing code': 'DEAWB4', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '740.036', 'Dealer product code': '210000008746', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Illinois, BUFFALO GROVE', 'Case diameter': '41.5 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Clasp': 'Fold clasp'}
# {'Listing code': 'D1IVI1', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '704.032', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '1999', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original papers, no original box', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New Jersey, Hoboken', 'Movement/Caliber': 'L961.1', 'Power reserve': '72 h', 'Number of jewels': '49', 'Case diameter': '38.5 mm', 'Water resistance': '1 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Brown', 'Clasp': 'Fold clasp', 'Clasp material': 'Rose Gold'}
# {'Listing code': '73BH49', 'Brand': 'A. Lange & Söhne', 'Movement': 'Manual winding', 'Case material': 'Silver', 'Year of production': '1920 (Approximation)', 'Condition': 'Good,                      (Light signs of wear or scratches),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Texas, Houston', 'Case diameter': '60 x 78 mm', 'Bezel material': 'Silver'}
# {'Listing code': '37ZE88', 'Brand': 'A. Lange & Söhne', 'Model': 'Richard Lange', 'Reference number': 'A.Lange and Sohne Richard Lange Pour Le Merite', 'Dealer product code': '13029', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2014', 'Condition': 'Unworn,                      (Mint condition, without signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Texas, Houston', 'Movement/Caliber': 'L072.1', 'Case diameter': '41.9 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'White', 'Bracelet color': 'Brown', 'Clasp': 'Fold clasp', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'D8G1Z9', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '405.031', 'Dealer product code': '4536934', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Pennsylvania', 'Power reserve': '60 h', 'Case diameter': '41 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Dial numerals': 'No numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle'}
# {}
# {'Listing code': '5D2AM5', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '211.032', 'Dealer product code': 'ALS019', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2014', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, California, Irvine', 'Movement/Caliber': 'L093.1', 'Power reserve': '72 h', 'Number of jewels': '21', 'Case diameter': '40 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial numerals': 'No numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle'}
# {'Listing code': 'D5QGZ8', 'Brand': 'A. Lange & Söhne', 'Reference number': '234.049', 'Dealer product code': '40382', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Year of production': 'Unknown', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Massachusetts, Boston', 'Power reserve': '72 h', 'Case diameter': '39 mm', 'Thickness': '8 mm', 'Crystal': 'Sapphire crystal', 'Dial numerals': 'Arabic numerals'}
# {'Listing code': 'DFD285', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '414.026', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2021', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Georgia, Alpharetta', 'Power reserve': '60 h', 'Case diameter': '39.5 mm', 'Water resistance': '3 ATM', 'Bezel material': 'White gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Blue', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'D7W4W9', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '381.031', 'Dealer product code': '210000007213', 'Movement': 'Automatic', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Illinois, BUFFALO GROVE', 'Case diameter': '38.5 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Clasp': 'Buckle'}
# {'Listing code': 'D5V1E2', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '191.028', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2018', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United Kingdom, London', 'Movement/Caliber': 'cal 121.1', 'Power reserve': '72 h', 'Number of jewels': '43', 'Case diameter': '38.5 mm', 'Bezel material': 'White gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Blue', 'Dial numerals': 'No numerals', 'Bracelet color': 'Beige', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'CZVGI3', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '330.025', 'Dealer product code': '57708w', 'Movement': 'Automatic', 'Case material': 'Platinum', 'Year of production': '2014', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, Hartsdale', 'Case diameter': '38.5 mm', 'Thickness': '10 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Clasp': 'Buckle', 'Clasp material': 'Platinum'}
# {'Listing code': 'DGWPT9', 'Brand': 'A. Lange & Söhne', 'Model': 'Odysseus', 'Reference number': '363.179', 'Case material': 'Steel', 'Bracelet material': 'Steel', 'Year of production': '2020', 'Condition': 'Unworn,                      (Mint condition, without signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Montana, Bozeman', 'Case diameter': '40.5 mm', 'Dial': 'Blue', 'Bracelet color': 'Steel'}
# {'Listing code': 'DGX224', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '405.031', 'Dealer product code': '4550083', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2020', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Pennsylvania', 'Case diameter': '41 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Dial numerals': 'No numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle'}
# {'Listing code': 'CWKZW4', 'Brand': 'A. Lange & Söhne', 'Model': 'Langematik', 'Reference number': '308.027', 'Dealer product code': '2109103', 'Movement': 'Automatic', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '1997', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Karlsruhe', 'Movement/Caliber': 'L921.4', 'Case diameter': '37 mm', 'Thickness': '10 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Bracelet color': 'Black', 'Bracelet length': '185 mm', 'Lug width': '19 mm, Size guide', 'Clasp': 'Buckle'}
# {'Listing code': 'CZ2N86', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '234.032', 'Dealer product code': '128551', 'Year of production': '2017', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Location': 'United States of America, Pennsylvania, Philadelphia', 'Case diameter': '39 mm', 'Dial': 'Silver'}
# {'Listing code': 'D9SK61', 'Brand': 'A. Lange & Söhne', 'Model': 'Cabaret', 'Reference number': '107.031', 'Dealer product code': '40503', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Massachusetts, Boston', 'Case diameter': '26 mm', 'Thickness': '9 mm', 'Crystal': 'Sapphire crystal'}
# {'Listing code': 'C02T29', 'Brand': 'A. Lange & Söhne', 'Model': 'Zeitwerk', 'Reference number': '140.029', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Year of production': '2017', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Nebraska, Lincoln', 'Movement/Caliber': 'L043.1', 'Power reserve': '36 h', 'Number of jewels': '68', 'Case diameter': '41.9 mm', 'Water resistance': '3 ATM', 'Bezel material': 'White gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Black', 'Clasp': 'Fold clasp', 'Clasp material': 'White Gold'}
# {'Listing code': 'D7VXL8', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '402.032', 'Dealer product code': '210000006139', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Illinois, BUFFALO GROVE', 'Case diameter': '39.5 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Clasp': 'Buckle'}
# {'Listing code': '64TEC2', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '421.025FE', 'Dealer product code': 'ALS026', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': '2014', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, California, Irvine', 'Case diameter': '41.9 mm', 'Bracelet color': 'Black', 'Clasp': 'Double-fold clasp', 'Clasp material': 'Platinum'}
# {'Listing code': '9UMLW5', 'Brand': 'A. Lange & Söhne', 'Model': 'Grand Lange 1', 'Reference number': '115.025', 'Dealer product code': '55526w', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Year of production': '2006', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, Hartsdale', 'Case diameter': '41 mm', 'Thickness': '10 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Clasp': 'Buckle', 'Clasp material': 'Platinum'}
# {'Listing code': 'CLPCQ7', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '330.032', 'Movement': 'Automatic', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Unworn,                      (Mint condition, without signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Aventura', 'Movement/Caliber': 'L085.1', 'Power reserve': '48 h', 'Case diameter': '38.5 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'No numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle'}
# {'Listing code': 'D8G1W3', 'Brand': 'A. Lange & Söhne', 'Model': 'Richard Lange', 'Reference number': '260.032', 'Dealer product code': '4475208', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2012', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Pennsylvania', 'Power reserve': '36 h', 'Case diameter': '40 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'White', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle'}
# {'Listing code': 'CI0BD2', 'Brand': 'A. Lange & Söhne', 'Model': 'Cabaret', 'Reference number': '107.032', 'Dealer product code': '2108507', 'Movement': 'Manual winding', 'Case material': 'Red gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '1999', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Karlsruhe', 'Movement/Caliber': 'L931.3', 'Case diameter': '42.5 x 25.5 mm', 'Thickness': '9 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Bracelet color': 'Black', 'Bracelet length': '190 mm', 'Lug width': '19 mm, Size guide', 'Clasp': 'Buckle'}
# {'Listing code': 'C8ORX7', 'Brand': 'A. Lange & Söhne', 'Model': 'Grand Lange 1', 'Reference number': '117.032', 'Dealer product code': 'ALS012', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2010 (Approximation)', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, California, Los Angeles', 'Movement/Caliber': 'L095.1', 'Power reserve': '72 h', 'Number of jewels': '42', 'Case diameter': '40.9 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'DBHA06', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '235.026', 'Dealer product code': '40668', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Year of production': 'Unknown', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Massachusetts, Boston', 'Case diameter': '38.5 mm', 'Thickness': '7.5 mm', 'Crystal': 'Sapphire crystal', 'Dial numerals': 'Arabic numerals'}
# {'Listing code': 'CNHL98', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '414.026', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2019', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Nebraska, Lincoln', 'Power reserve': '60 h', 'Case diameter': '39.5 mm', 'Water resistance': '3 ATM', 'Bezel material': 'White gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Blue', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'D7W562', 'Brand': 'A. Lange & Söhne', 'Model': 'Grand Lange 1', 'Reference number': '115.032', 'Dealer product code': '210000010144', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Illinois, BUFFALO GROVE', 'Case diameter': '42 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Clasp': 'Buckle'}
# {'Listing code': 'ARSYP6', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '424.038', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Leather', 'Year of production': '2020 (Approximation)', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, California, Irvine', 'Dial': 'Grey'}
# {'Listing code': 'D4XGK5', 'Brand': 'A. Lange & Söhne', 'Model': 'Grand Lange 1', 'Reference number': '117.028', 'Dealer product code': '57700w', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Year of production': '2015', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, Hartsdale', 'Case diameter': '41 mm', 'Thickness': '10 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Dial numerals': 'Roman numerals', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'A7HR85', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '235.032', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2021', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Aventura', 'Movement/Caliber': 'L051.1', 'Power reserve': '55 h', 'Number of jewels': '23', 'Frequency': '21600 A/h', 'Case diameter': '38.5 mm', 'Thickness': '8.8 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'BPER98', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '730.032F', 'Dealer product code': '4437810', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Pennsylvania', 'Case diameter': '39 mm', 'Water resistance': '3 ATM', 'Dial': 'White', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle'}
# {'Listing code': 'CMM0Q0', 'Brand': 'A. Lange & Söhne', 'Model': 'Cabaret', 'Reference number': '107.031', 'Dealer product code': '2109551', 'Movement': 'Manual winding', 'Case material': 'Red gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2002', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Karlsruhe', 'Movement/Caliber': 'L.931.3', 'Case diameter': '36 x 25.5 mm', 'Thickness': '9 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Bracelet color': 'Black', 'Bracelet length': '190 mm', 'Lug width': '19 mm, Size guide', 'Clasp': 'Buckle'}
# {'Listing code': 'C4XRH7', 'Brand': 'A. Lange & Söhne', 'Model': 'Zeitwerk', 'Reference number': '140.029', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Leather', 'Year of production': '2013', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Miami', 'Movement/Caliber': 'L043.1', 'Power reserve': '36 h', 'Number of jewels': '68', 'Case diameter': '41.9 mm', 'Water resistance': '3 ATM', 'Bezel material': 'White gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'DCDWJ5', 'Brand': 'A. Lange & Söhne', 'Model': 'Grand Lange 1', 'Reference number': '139.035F', 'Dealer product code': '40692', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Year of production': 'Unknown', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Massachusetts, Boston', 'Power reserve': '72 h', 'Case diameter': '41 mm', 'Thickness': '9.5 mm', 'Crystal': 'Sapphire crystal', 'Dial numerals': 'Roman numerals'}
# {'Listing code': 'CYAX40', 'Brand': 'A. Lange & Söhne', 'Model': 'Zeitwerk', 'Reference number': '140.032', 'Dealer product code': '224724829540', 'Movement': 'Automatic', 'Case material': 'Rose gold', 'Bracelet material': 'Leather', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, Smithtown', 'Case diameter': '41.9 mm', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'White', 'Bracelet color': 'Brown', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'D7VW97', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '421.032', 'Dealer product code': '210000008898', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Illinois, BUFFALO GROVE', 'Case diameter': '42 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Clasp': 'Fold clasp'}
# {'Listing code': '5D2BU9', 'Brand': 'A. Lange & Söhne', 'Model': 'Richard Lange', 'Reference number': '232.025', 'Dealer product code': 'ALS014', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, California, Irvine', 'Movement/Caliber': 'L041.2', 'Power reserve': '38 h', 'Case diameter': '40.5 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'Platinum'}
# {'Listing code': 'DC3395', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '219.026', 'Dealer product code': 'MXWQT', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2017', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Location': 'United States of America, Massachusetts, Boston', 'Movement/Caliber': 'L941.1', 'Power reserve': '45 h', 'Number of jewels': '21', 'Case diameter': '35 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'A7HG13', 'Brand': 'A. Lange & Söhne', 'Model': 'Richard Lange', 'Reference number': '232.032', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2021', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Aventura', 'Movement/Caliber': 'L041.2', 'Power reserve': '38 h', 'Number of jewels': '26', 'Frequency': '21600 A/h', 'Case diameter': '40.5 mm', 'Thickness': '10.5 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'CCQ7I3', 'Brand': 'A. Lange & Söhne', 'Model': 'Zeitwerk', 'Reference number': '147.025F', 'Dealer product code': '4463832', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Pennsylvania', 'Power reserve': '36 h', 'Case diameter': '44 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle'}
# {'Listing code': 'CZ35Q9', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '238.032', 'Dealer product code': '2110546', 'Movement': 'Manual winding', 'Case material': 'Red gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2018', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Karlsruhe', 'Movement/Caliber': 'L051.3', 'Case diameter': '40 mm', 'Thickness': '10.5 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Bracelet color': 'Bordeaux', 'Bracelet length': '190 mm', 'Lug width': '20 mm, Size guide', 'Clasp': 'Buckle'}
# {'Listing code': '63RM67', 'Brand': 'A. Lange & Söhne', 'Model': 'Richard Lange', 'Reference number': '260.032', 'Dealer product code': '202584189149', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Leather', 'Year of production': 'Unknown', 'Condition': 'Unworn,                      (Mint condition, without signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Boca Raton', 'Case diameter': '40.5 mm', 'Thickness': '8.8 mm', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'White', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle'}
# {'Listing code': 'D6DFC1', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '223.032', 'Dealer product code': '40672', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Year of production': 'Unknown', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Massachusetts, Boston', 'Power reserve': '45 h', 'Case diameter': '37.5 mm', 'Thickness': '9.5 mm', 'Crystal': 'Sapphire crystal'}
# {'Listing code': 'BU0OI6', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '206.032', 'Dealer product code': 'ALS1815R', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Year of production': '2005', 'Condition': 'Good,                      (Light signs of wear or scratches),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, New York', 'Movement/Caliber': 'L 941.1', 'Power reserve': '45 h', 'Number of jewels': '21', 'Case diameter': '36 mm', 'Thickness': '7.5 mm', 'Water resistance': '10 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'D7VWI8', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '720.025', 'Dealer product code': '210000007252', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Illinois, BUFFALO GROVE', 'Case diameter': '42 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Clasp': 'Buckle'}
# {'Listing code': 'CKMH88', 'Brand': 'A. Lange & Söhne', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Location': 'United States of America, California, Irvine'}
# {}
# {'Listing code': 'B9WOL7', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '384.032', 'Movement': 'Automatic', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2022', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Aventura', 'Movement/Caliber': 'L086.5', 'Base caliber': 'L086.1', 'Power reserve': '72 h', 'Number of jewels': '40', 'Frequency': '21600 A/h', 'Case diameter': '40 mm', 'Thickness': '9.8 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'No numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'C523G0', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '385.026', 'Dealer product code': '4491718', 'Movement': 'Automatic', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Pennsylvania', 'Power reserve': '72 h', 'Case diameter': '40 mm', 'Water resistance': 'Not water resistant', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'No numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle'}
# {'Listing code': 'DF7I98', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '330.026', 'Dealer product code': '2200352', 'Movement': 'Automatic', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2010', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Chemnitz', 'Movement/Caliber': 'L085.1', 'Case diameter': '38.5 mm', 'Thickness': '10 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Bracelet color': 'Brown', 'Bracelet length': '190 mm', 'Lug width': '20 mm, Size guide', 'Clasp': 'Buckle'}
# {'Listing code': '6NS5T1', 'Brand': 'A. Lange & Söhne', 'Model': 'Richard Lange', 'Reference number': '180.026', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2021', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, New York'}
# {'Listing code': 'DC2H01', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '101.022', 'Dealer product code': '40505', 'Movement': 'Manual winding', 'Case material': 'Yellow gold', 'Year of production': 'Unknown', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Massachusetts, Boston', 'Case diameter': '38.5 mm', 'Thickness': '9.5 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial numerals': 'Roman numerals'}
# {'Listing code': '63RP31', 'Brand': 'A. Lange & Söhne', 'Model': 'Richard Lange', 'Reference number': '760.032F', 'Dealer product code': '173773240093', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Leather', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Boca Raton', 'Case diameter': '41.9 mm', 'Thickness': '12.5 mm', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'White', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Brown', 'Clasp': 'Fold clasp', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'D7W406', 'Brand': 'A. Lange & Söhne', 'Model': 'Grand Lange 1', 'Reference number': '117.032', 'Dealer product code': '210000007913', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Illinois, BUFFALO GROVE', 'Case diameter': '41 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Clasp': 'Buckle'}
# {'Listing code': 'CKMHQ0', 'Brand': 'A. Lange & Söhne', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Location': 'United States of America, California, Irvine'}
# {'Listing code': 'CNQT43', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '320.032', 'Dealer product code': 'AIUQW', 'Movement': 'Automatic', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2013', 'Condition': 'Unworn,                      (Mint condition, without signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Massachusetts, Boston', 'Movement/Caliber': 'L021.1', 'Power reserve': '50 h', 'Case diameter': '39.5 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle'}
# {'Listing code': 'B2FU54', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '380.042', 'Movement': 'Automatic', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2021', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Aventura', 'Movement/Caliber': 'L086.1', 'Power reserve': '72 h', 'Number of jewels': '31', 'Frequency': '21600 A/h', 'Case diameter': '38.5 mm', 'Thickness': '7.8 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Brown', 'Dial numerals': 'No numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'COHJ48', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '424.038F', 'Dealer product code': '4438032', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2020', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Pennsylvania', 'Power reserve': '55 h', 'Case diameter': '43 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Grey', 'Dial numerals': 'No numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle'}
# {'Listing code': 'CYLMD1', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '219.047', 'Dealer product code': '2110713', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Leather', 'Year of production': '2018', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Womens watch', 'Location': 'Germany, Karlsruhe', 'Movement/Caliber': 'L941.1', 'Case diameter': '35 mm', 'Thickness': '7.3 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Mother of pearl', 'Bracelet color': 'White', 'Bracelet length': '165 mm', 'Lug width': '18 mm, Size guide', 'Clasp': 'Buckle'}
# ...
# {'Listing code': '7HW7I4', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '380.027', 'Dealer product code': '1131', 'Movement': 'Automatic', 'Case material': 'White gold', 'Bracelet material': 'Leather', 'Year of production': '2015 (Approximation)', 'Condition': 'Unworn,                      (Mint condition, without signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United Kingdom, London', 'Base caliber': 'L086.1', 'Number of jewels': '21', 'Case diameter': '38.5 mm', 'Thickness': '7.8 mm', 'Water resistance': '3 ATM', 'Bezel material': 'White gold', 'Crystal': 'Sapphire crystal', 'Dial': 'White', 'Dial numerals': 'No numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'D0D3Q0', 'Brand': 'A. Lange & Söhne', 'Movement': 'Manual winding', 'Case material': 'Yellow gold', 'Year of production': '1888', 'Condition': 'Good,                      (Light signs of wear or scratches),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Berlin', 'Dial': 'White'}
# {'Listing code': 'B6X1K7', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '405.035', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Unworn,                      (Mint condition, without signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, New York', 'Movement/Caliber': 'L951.6', 'Power reserve': '60 h', 'Number of jewels': '46', 'Case diameter': '41 mm', 'Thickness': '13.1 mm', 'Bezel material': 'Platinum', 'Crystal': 'Sapphire crystal', 'Dial': 'Black', 'Dial numerals': 'No numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'Platinum'}
# {}
# {'Listing code': '93EM69', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '381.031', 'Dealer product code': '2569', 'Movement': 'Automatic', 'Case material': 'Rose gold', 'Bracelet material': 'Leather', 'Year of production': '2022', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Sunny Isles Beach', 'Case diameter': '38.5 mm', 'Thickness': '9.6 mm', 'Dial': 'Black', 'Bracelet color': 'Black', 'Clasp': 'Buckle'}
# {'Listing code': 'CM1DJ4', 'Brand': 'A. Lange & Söhne', 'Model': 'Datograph', 'Reference number': '403.032', 'Dealer product code': '10/2021/1237/1', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Czech Republic, Praha 1', 'Power reserve': '36 h', 'Number of jewels': '40', 'Case diameter': '39 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Brown', 'Clasp': 'Buckle', 'Clasp material': 'Rose Gold'}
# {'Listing code': '68NLW2', 'Brand': 'A. Lange & Söhne', 'Model': 'Little Lange 1', 'Reference number': '182.030', 'Dealer product code': '22175', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Year of production': 'Unknown', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Womens watch', 'Location': 'United States of America, Florida, North Miami Beach', 'Power reserve': '72 h', 'Case diameter': '36.8 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Clasp': 'Buckle'}
# {'Listing code': 'BVCDK5', 'Brand': 'A. Lange & Söhne', 'Dealer product code': '17521', 'Movement': 'Manual winding', 'Case material': 'Yellow gold', 'Year of production': '1873', 'Condition': 'Good,                      (Light signs of wear or scratches),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Dresden', 'Movement/Caliber': '37', 'Number of jewels': '20', 'Frequency': '18000 A/h', 'Case diameter': '43 mm', 'Thickness': '13 mm', 'Crystal': 'Plastic', 'Dial': 'White', 'Dial numerals': 'Roman numerals'}
# {'Listing code': 'DGIJ32', 'Brand': 'A. Lange & Söhne', 'Model': 'Zeitwerk', 'Reference number': '140.029', 'Dealer product code': 'SD024245', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Leather', 'Year of production': '2018 (Approximation)', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United Kingdom, London', 'Case diameter': '42 mm'}
# {'Listing code': 'CIHKE3', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '101.021', 'Dealer product code': '1225', 'Movement': 'Manual winding', 'Case material': 'Yellow gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Location': 'Austria, Baden bei Wien', 'Case diameter': '38.5 mm'}
# {'Listing code': 'CU7PN4', 'Brand': 'A. Lange & Söhne', 'Movement': 'Manual winding', 'Case material': 'Yellow gold', 'Year of production': '1900 (Approximation)', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, München', 'Case diameter': '53 mm', 'Thickness': '14 mm', 'Water resistance': 'Not water resistant', 'Bezel material': 'Yellow gold', 'Crystal': 'Glass', 'Dial': 'White', 'Dial numerals': 'Arabic numerals'}
# {'Listing code': '9DVT86', 'Brand': 'A. Lange & Söhne', 'Reference number': 'FL 23883', 'Dealer product code': '--', 'Movement': 'Manual winding', 'Case material': 'Steel', 'Bracelet material': 'Leather', 'Year of production': '1942', 'Condition': 'Good,                      (Light signs of wear or scratches),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Berlin', 'Dial': 'Black'}
# {'Listing code': 'C28ZA6', 'Brand': 'A. Lange & Söhne', 'Model': '1815', 'Reference number': '233.021', 'Movement': 'Manual winding', 'Case material': 'Yellow gold', 'Bracelet material': 'Leather', 'Year of production': 'Unknown', 'Condition': 'Unworn,                      (Mint condition, without signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, New York, New York', 'Dial': 'Silver'}
# {'Listing code': '7WPT59', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '201.027', 'Dealer product code': '2227', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Leather', 'Year of production': '2022', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Sunny Isles Beach', 'Power reserve': '45 h', 'Number of jewels': '21', 'Case diameter': '37 mm', 'Thickness': '5.9 mm', 'Dial': 'Silver', 'Bracelet color': 'Black', 'Clasp': 'Buckle'}
# {'Listing code': 'CHJI05', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '307.026', 'Dealer product code': '09/2021/0406/4', 'Movement': 'Automatic', 'Case material': 'White gold', 'Bracelet material': 'Leather', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Czech Republic, Praha 1', 'Case diameter': '40 mm', 'Dial': 'Silver', 'Dial numerals': 'No numerals'}
# {'Listing code': 'BAE9E3', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '136.032', 'Dealer product code': '58910', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, North Miami Beach', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Dial': 'Silver', 'Clasp': 'Buckle'}
# {'Listing code': 'DFU885', 'Brand': 'A. Lange & Söhne', 'Dealer product code': '45921', 'Movement': 'Manual winding', 'Case material': 'Silver', 'Year of production': '1944', 'Condition': 'Good,                      (Light signs of wear or scratches),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Dresden', 'Movement/Caliber': '48', 'Power reserve': '35 h', 'Number of jewels': '16', 'Frequency': '18000 A/h', 'Case diameter': '59 mm', 'Thickness': '18 mm', 'Crystal': 'Plastic', 'Dial': 'Silver', 'Dial numerals': 'Arabic numerals'}
# {'Listing code': 'A39SF9', 'Brand': 'A. Lange & Söhne', 'Model': 'Lange 1', 'Reference number': '101.021', 'Dealer product code': 'AD4769', 'Movement': 'Manual winding', 'Case material': 'Yellow gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Good,                      (Light signs of wear or scratches),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Düsseldorf', 'Case diameter': '38.5 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Clasp': 'Buckle'}
# {'Listing code': 'CL3MM9', 'Brand': 'A. Lange & Söhne', 'Reference number': '301.027', 'Movement': 'Automatic', 'Case material': 'White gold', 'Bracelet material': 'Crocodile skin', 'Year of production': '2004 (Approximation)', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Australia, Mount Eliza', 'Case diameter': '36.8 mm', 'Thickness': '8.2 mm', 'Dial': 'Black', 'Bracelet color': 'Black', 'Clasp': 'Buckle', 'Clasp material': 'White Gold'}
# {'Listing code': 'DEN8Z9', 'Brand': 'A. Lange & Söhne', 'Model': 'Richard Lange', 'Reference number': '232.032F', 'Dealer product code': 'A18360', 'Movement': 'Manual winding', 'Case material': 'Rose gold', 'Bracelet material': 'Leather', 'Year of production': '2007', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, München', 'Movement/Caliber': 'L041.2', 'Power reserve': '38 h', 'Number of jewels': '26', 'Case diameter': '40.5 mm', 'Water resistance': '3 ATM', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Clasp': 'Fold clasp', 'Clasp material': 'Rose Gold'}
# {'Listing code': 'CRWNB8', 'Brand': 'A. Lange & Söhne', 'Movement': 'Manual winding', 'Year of production': '1917 (Approximation)', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Germany, Berlin', 'Dial': 'White'}
# {'Listing code': 'D1BZC6', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '105.027', 'Dealer product code': 'SD022096', 'Movement': 'Manual winding', 'Case material': 'White gold', 'Bracelet material': 'Leather', 'Year of production': '2000 (Approximation)', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'No original box, no original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United Kingdom, London', 'Case diameter': '34 mm'}
# {'Listing code': 'CCVRD9', 'Brand': 'A. Lange & Söhne', 'Model': 'Grand Lange 1', 'Reference number': '117.025', 'Dealer product code': '2606', 'Movement': 'Manual winding', 'Case material': 'Platinum', 'Bracelet material': 'Leather', 'Year of production': '2022', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, Sunny Isles Beach', 'Power reserve': '72 h', 'Number of jewels': '42', 'Case diameter': '40.9 mm', 'Thickness': '8.8 mm', 'Dial': 'Silver', 'Dial numerals': 'Roman numerals', 'Bracelet color': 'Black', 'Clasp': 'Buckle'}
# {'Listing code': 'B0CU86', 'Brand': 'A. Lange & Söhne', 'Model': 'Langematik', 'Reference number': '308.021', 'Dealer product code': '02/2021/0328/9', 'Movement': 'Automatic', 'Case material': 'Yellow gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'Very good,                      (Worn with little to no signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'Czech Republic, Praha 1', 'Case diameter': '37 mm', 'Crystal': 'Sapphire crystal', 'Dial': 'Silver', 'Clasp material': 'Yellow gold'}
# {'Listing code': '6IM5L1', 'Brand': 'A. Lange & Söhne', 'Model': 'Saxonia', 'Reference number': '381.031', 'Dealer product code': '32648', 'Movement': 'Automatic', 'Case material': 'Rose gold', 'Bracelet material': 'Crocodile skin', 'Year of production': 'Unknown', 'Condition': 'New,                      (Brand new, without any signs of wear),', 'Scope of delivery': 'Original box, original papers', 'Gender': 'Mens watch/Unisex', 'Location': 'United States of America, Florida, North Miami Beach', 'Power reserve': '72 h', 'Case diameter': '38.5 mm', 'Water resistance': '3 ATM', 'Bezel material': 'Rose gold', 'Dial': 'Black', 'Clasp': 'Buckle'}
# {'Listing code': 'CYU923', 'Brand': 'A. Lange & Söhne', 'Dealer product code': '41121', 'Movement': 'Manual winding', 'Case material': 'Yellow gold', 'Bracelet material': 'Textile', 'Year of production': '1933', 'Condition': 'Fair,                      (Obvious signs of wear or scratches),', 'Scope of delivery': 'Original papers, no original box', 'Gender': 'Womens watch', 'Location': 'Germany, Dresden', 'Movement/Caliber': '19,7 mm', 'Number of jewels': '17', 'Frequency': '18000 A/h', 'Case diameter': '21 mm', 'Thickness': '8 mm', 'Crystal': 'Plastic', 'Dial': 'Gold', 'Dial numerals': 'Arabic numerals', 'Bracelet color': 'Black', 'Clasp': 'Fold clasp', 'Clasp material': 'Yellow gold'}
# {'Listing code': 'CDIZQ2', 'Brand': 'A. Lange & Söhne', 'Reference number': '761.050', 'Movement': 'Manual winding', 'Year of production': '2011 (Approximation)', 'Condition': 'Good,                      (Light signs of wear or scratches),', 'Scope of delivery': 'Original papers, no original box', 'Gender': 'Mens watch/Unisex', 'Location': 'China, Minhang District', 'Movement/Caliber': 'Cal.L072.1', 'Power reserve': '36 h', 'Frequency': '21600 Hz', 'Case diameter': '42 mm'}

# %%
def get_ad_csv(input: dict):
    
    attributes_df = pd.DataFrame().from_dict(input, orient = 'index').transpose()
    attributes_df.to_csv('attributes_list.csv', sep = ',', index = False)

# %%
# dict1 = get_all_attributes()
# df = pd.DataFrame().from_dict(dict1, orient = 'index').transpose()


# df

# %%
get_ad_csv(power)

# %%
#fetch_attributes('https://www.chrono24.com/rolex/submariner-no-date-oyster-perpetual-ref-14060m-serial-number-m366678--id22288653.htm')
